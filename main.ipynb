# %%
from pandas import read_csv, isna

# %%
df = read_csv("autos.csv",encoding='cp1252')

# %%
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# ...

# %%
df.drop_duplicates().__len__()
# Out:
# 371524

# %%
df.__len__()
# Out:
# 371528

# %%
df.drop_duplicates(inplace= True)
df.reset_index(inplace=True)

# %%
lst = [str(i).capitalize() for i in df.columns]
lst
# Out:
# ['Index',
#  'Datecrawled',
#  'Name',
#  'Seller',
#  'Offertype',
#  'Price',
#  'Abtest',
#  'Vehicletype',
#  'Yearofregistration',
#  'Gearbox',
#  'Powerps',
#  'Model',
#  'Kilometer',
#  'Monthofregistration',
#  'Fueltype',
#  'Brand',
#  'Notrepaireddamage',
#  'Datecreated',
#  'Nrofpictures',
#  'Postalcode',
#  'Lastseen']

# %%
lst[1] = "DateCrawled"
lst[4] = "OfferType"
lst[7] = "VehicleType"
lst[8] = "YearOfRegistration"
lst[10] = "PowerPS"
lst[13] = "MonthOfRegistration"
lst[14] = "FuelType"
lst[16] = "NotRepairedDamage"
lst[17] = "DateCreated"
lst[18] = "NoOfPictures"
lst[19] = "PostalCode"
lst[20] = "LastSeen"
lst
# Out:
# ['Index',
#  'DateCrawled',
#  'Name',
#  'Seller',
#  'OfferType',
#  'Price',
#  'Abtest',
#  'VehicleType',
#  'YearOfRegistration',
#  'Gearbox',
#  'PowerPS',
#  'Model',
#  'Kilometer',
#  'MonthOfRegistration',
#  'FuelType',
#  'Brand',
#  'NotRepairedDamage',
#  'DateCreated',
#  'NoOfPictures',
#  'PostalCode',
#  'LastSeen']

# %%
df.columns = lst

# %%
df.head()
# Out:
#    Index          DateCrawled                            Name  Seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  privat
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat
#
#   OfferType  Price Abtest VehicleType  YearOfRegistration    Gearbox  ...  \
# 0   Angebot    480   test         NaN                1993    manuell  ...
# 1   Angebot  18300   test       coupe                2011    manuell  ...
# 2   Angebot   9800   test         suv                2004  automatik  ...
# 3   Angebot   1500   test  kleinwagen                2001    manuell  ...
# 4   Angebot   3600   test  kleinwagen                2008    manuell  ...
#
#    Model Kilometer  MonthOfRegistration  FuelType       Brand  \
# ...

# %%
lst_column_with_nan_values = []
for i in df.columns :
    if df[isna(df[i])].__len__()  != 0 :
        lst_column_with_nan_values.append(i)

# %%
lst_column_with_nan_values
# Out:
# ['VehicleType', 'Gearbox', 'Model', 'FuelType', 'NotRepairedDamage']

# %%
df["Name"].value_counts()
# Out:
# Name
# Ford_Fiesta                                              657
# BMW_318i                                                 627
# Opel_Corsa                                               622
# Volkswagen_Golf_1.4                                      603
# BMW_316i                                                 523
#                                                         ...
# Audi_A4_Avant_Klima_Gruene_Plakette_TÜV_&AU_NEU_XENON      1
# Renault_clio_in_gold_450VB_!!                              1
# Fiat_Doblo_1.6_Multijet                                    1
# Renault_Laguna_1                                           1
# BMW_M135i_vollausgestattet_NP_52.720____Euro               1
# Name: count, Length: 233531, dtype: int64

# %%
df["Seller"].value_counts()
# Out:
# Seller
# privat        371521
# gewerblich         3
# Name: count, dtype: int64

# %%
# "gewerblich" is an German word which means "Commercial" ...
lst_exception_rows = []
lst = []
for i in df["Seller"] :
    try :
        lst.append("Private" if i == "privat" else "Commercial")
    except :
        lst_exception_rows.append(i)
df["Seller"] = lst

# %%
lst_exception_rows
# Out:
# []

# %%
df["Seller"].value_counts()
# Out:
# Seller
# Private       371521
# Commercial         3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Index          DateCrawled                            Name   Seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  Private
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private
#
#   OfferType  Price Abtest VehicleType  YearOfRegistration    Gearbox  ...  \
# 0   Angebot    480   test         NaN                1993    manuell  ...
# 1   Angebot  18300   test       coupe                2011    manuell  ...
# 2   Angebot   9800   test         suv                2004  automatik  ...
# 3   Angebot   1500   test  kleinwagen                2001    manuell  ...
# 4   Angebot   3600   test  kleinwagen                2008    manuell  ...
#
#    Model Kilometer  MonthOfRegistration  FuelType       Brand  \
# ...

# %%
df["OfferType"].value_counts()
# Out:
# OfferType
# Angebot    371512
# Gesuch         12
# Name: count, dtype: int64

# %%
# In German, "Angebot" means "Proposal" and "Gesuch" means "Request"
lst_exception_rows = []
lst = []
for i in df["OfferType"] :
    try :
        lst.append( "Proposal" if i == "Angebot" else "Request")
    except :
        lst_exception_rows.append(i)
df["OfferType"] = lst

# %%
lst_exception_rows
# Out:
# []

# %%
df.head()
# Out:
#    Index          DateCrawled                            Name   Seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  Private
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private
#
#   OfferType  Price Abtest VehicleType  YearOfRegistration    Gearbox  ...  \
# 0  Proposal    480   test         NaN                1993    manuell  ...
# 1  Proposal  18300   test       coupe                2011    manuell  ...
# 2  Proposal   9800   test         suv                2004  automatik  ...
# 3  Proposal   1500   test  kleinwagen                2001    manuell  ...
# 4  Proposal   3600   test  kleinwagen                2008    manuell  ...
#
#    Model Kilometer  MonthOfRegistration  FuelType       Brand  \
# ...

# %%
df.tail()
# Out:
#          Index          DateCrawled  \
# 371519  371523  2016-03-14 17:48:27
# 371520  371524  2016-03-05 19:56:21
# 371521  371525  2016-03-19 18:57:12
# 371522  371526  2016-03-20 19:41:08
# 371523  371527  2016-03-07 19:39:19
#
#                                                 Name   Seller OfferType  \
# 371519                    Suche_t4___vito_ab_6_sitze  Private  Proposal
# 371520         Smart_smart_leistungssteigerung_100ps  Private  Proposal
# 371521            Volkswagen_Multivan_T4_TDI_7DC_UY2  Private  Proposal
# 371522                        VW_Golf_Kombi_1_9l_TDI  Private  Proposal
# 371523  BMW_M135i_vollausgestattet_NP_52.720____Euro  Private  Proposal
#
#         Price   Abtest VehicleType  YearOfRegistration    Gearbox  ...  \
# 371519   2200     test         NaN                2005        NaN  ...
# 371520   1199     test      cabrio                2000  automatik  ...
# 371521   9200     test         bus                1996    manuell  ...
# ...

# %%
lst_exception_rows = []
for i in range(df.__len__()) :
    try :
        int(df.loc[i,"Price"])
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
df.__len__()
# Out:
# 371524

# %%
df["Abtest"].value_counts()
# Out:
# Abtest
# test       192583
# control    178941
# Name: count, dtype: int64

# %%
lst_exception_rows = []
for i in range(df.__len__() ) :
    try :
        df.loc[i,"Abtest"] = str(df.loc[i,"Abtest"]).capitalize()
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
df["VehicleType"].value_counts()
# Out:
# VehicleType
# limousine     95894
# kleinwagen    80022
# kombi         67563
# bus           30201
# cabrio        22898
# coupe         19013
# suv           14707
# andere         3357
# Name: count, dtype: int64

# %%
lst_exception_rows = []
lst = []
for i in df["VehicleType"] :
    try :
        lst.append("-" if isna(i) else str(i).capitalize() )
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
lst.__len__() == df.__len__()
# Out:
# True

# %%
df["VehicleType"] = lst

# %%
df.head()
# Out:
#    Index          DateCrawled                            Name   Seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  Private
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private
#
#   OfferType  Price Abtest VehicleType  YearOfRegistration    Gearbox  ...  \
# 0  Proposal    480   Test           -                1993    manuell  ...
# 1  Proposal  18300   Test       Coupe                2011    manuell  ...
# 2  Proposal   9800   Test         Suv                2004  automatik  ...
# 3  Proposal   1500   Test  Kleinwagen                2001    manuell  ...
# 4  Proposal   3600   Test  Kleinwagen                2008    manuell  ...
#
#    Model Kilometer  MonthOfRegistration  FuelType       Brand  \
# ...

# %%
df["YearOfRegistration"].value_counts()
# Out:
# YearOfRegistration
# 2000    24551
# 1999    22766
# 2005    22316
# 2006    20230
# 2001    20217
#         ...
# 2066        1
# 9450        1
# 3200        1
# 1925        1
# 3500        1
# Name: count, Length: 155, dtype: int64

# %%
sum = 0
for i in df["YearOfRegistration"].value_counts():
    sum+=i
sum == df.__len__()
# Out:
# True

# %%
df.head()
# Out:
#    Index          DateCrawled                            Name   Seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  Private
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private
#
#   OfferType  Price Abtest VehicleType  YearOfRegistration    Gearbox  ...  \
# 0  Proposal    480   Test           -                1993    manuell  ...
# 1  Proposal  18300   Test       Coupe                2011    manuell  ...
# 2  Proposal   9800   Test         Suv                2004  automatik  ...
# 3  Proposal   1500   Test  Kleinwagen                2001    manuell  ...
# 4  Proposal   3600   Test  Kleinwagen                2008    manuell  ...
#
#    Model Kilometer  MonthOfRegistration  FuelType       Brand  \
# ...

# %%
df["Gearbox"].value_counts()
# Out:
# Gearbox
# manuell      274212
# automatik     77103
# Name: count, dtype: int64

# %%
lst_exception_rows = []
lst = []

for i in range(df.__len__()) :
    try :
        val = df.loc[i,"Gearbox"]
        if isna(val) : val = "-"
        elif val == "automatik" : val = "Automatic"
        elif val == "manuell" : val = "Manual"
        lst.append(val)
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
lst.__len__() == df.__len__()
# Out:
# True

# %%
lst.count("Manual")
# Out:
# 274212

# %%
lst.count("Automatic")
# Out:
# 77103

# %%
df["Gearbox"] = lst

# %%
df.head()
# Out:
#    Index          DateCrawled                            Name   Seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  Private
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private
#
#   OfferType  Price Abtest VehicleType  YearOfRegistration    Gearbox  ...  \
# 0  Proposal    480   Test           -                1993     Manual  ...
# 1  Proposal  18300   Test       Coupe                2011     Manual  ...
# 2  Proposal   9800   Test         Suv                2004  Automatic  ...
# 3  Proposal   1500   Test  Kleinwagen                2001     Manual  ...
# 4  Proposal   3600   Test  Kleinwagen                2008     Manual  ...
#
#    Model Kilometer  MonthOfRegistration  FuelType       Brand  \
# ...

# %%
df.drop(columns=["Index"],inplace= True)

# %%
df.head()
# Out:
#            DateCrawled                            Name   Seller OfferType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  Private  Proposal
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private  Proposal
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private  Proposal
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private  Proposal
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private  Proposal
#
#    Price Abtest VehicleType  YearOfRegistration    Gearbox  PowerPS  Model  \
# 0    480   Test           -                1993     Manual        0   golf
# 1  18300   Test       Coupe                2011     Manual      190    NaN
# 2   9800   Test         Suv                2004  Automatic      163  grand
# 3   1500   Test  Kleinwagen                2001     Manual       75   golf
# 4   3600   Test  Kleinwagen                2008     Manual       69  fabia
#
# ...

# %%
df["PowerPS"].value_counts()
# Out:
# PowerPS
# 0       40820
# 75      24035
# 60      15907
# 150     15442
# 140     13585
#         ...
# 1339        1
# 780         1
# 6920        1
# 1659        1
# 564         1
# Name: count, Length: 794, dtype: int64

# %%
sum = 0
for i in df["PowerPS"].value_counts():
    sum+=i
sum == df.__len__()
# Out:
# True

# %%
df[isna(df["PowerPS"])]
# Out:
# Empty DataFrame
# Columns: [DateCrawled, Name, Seller, OfferType, Price, Abtest, VehicleType, YearOfRegistration, Gearbox, PowerPS, Model, Kilometer, MonthOfRegistration, FuelType, Brand, NotRepairedDamage, DateCreated, NoOfPictures, PostalCode, LastSeen]
# Index: []

# %%
df["Model"].value_counts()
# Out:
# Model
# golf               30070
# andere             26399
# 3er                20567
# polo               13092
# corsa              12573
#                    ...
# serie_2                8
# rangerover             6
# serie_3                4
# serie_1                2
# discovery_sport        1
# Name: count, Length: 251, dtype: int64

# %%
lst_exception_rows = []
lst = []
for val in df["Model"] :
    try :
        if isna(val) : lst.append("-")
        else : lst.append(str(val).capitalize())
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
lst.__len__() == df.__len__()
# Out:
# True

# %%
df["Model"] = lst

# %%
df.head()
# Out:
#            DateCrawled                            Name   Seller OfferType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  Private  Proposal
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private  Proposal
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private  Proposal
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private  Proposal
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private  Proposal
#
#    Price Abtest VehicleType  YearOfRegistration    Gearbox  PowerPS  Model  \
# 0    480   Test           -                1993     Manual        0   Golf
# 1  18300   Test       Coupe                2011     Manual      190      -
# 2   9800   Test         Suv                2004  Automatic      163  Grand
# 3   1500   Test  Kleinwagen                2001     Manual       75   Golf
# 4   3600   Test  Kleinwagen                2008     Manual       69  Fabia
#
# ...

# %%
lst_exception_rows = []
for i in df["Kilometer"] :
    try :
        int(i)
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
df["MonthOfRegistration"].value_counts()
# Out:
# MonthOfRegistration
# 0     37675
# 3     36170
# 6     33166
# 4     30918
# 5     30631
# 7     28956
# 10    27337
# 11    25489
# 12    25380
# 9     25074
# 1     24560
# 8     23765
# 2     22403
# Name: count, dtype: int64

# %%
sum = 0
for i in df["MonthOfRegistration"].value_counts() :
    sum+= i
sum == df.__len__()
# Out:
# True

# %%
df["FuelType"].value_counts()
# Out:
# FuelType
# benzin     223854
# diesel     107745
# lpg          5378
# cng           571
# hybrid        278
# andere        208
# elektro       104
# Name: count, dtype: int64

# %%
df[isna(df["FuelType"])].__len__()
# Out:
# 33386

# %%
lst_exception_rows = []
lst = []
fuel_map = {"benzin" : "Gasoline",
             "diesel" : "Diesel",
             "lpg" : "LPG",
             "cng" : "CNG",
             "hybrid" : "Hybrid",
             "andere" : "Other",
             "elektro" : "Electric"
            }
for i in df["FuelType"] :
    try :
        if isna(i) : lst.append("Other")
        else : lst.append(fuel_map[i])
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
lst.__len__() == df.__len__()
# Out:
# True

# %%
df["FuelType"] = lst

# %%
df["FuelType"].value_counts()
# Out:
# FuelType
# Gasoline    223854
# Diesel      107745
# Other        33594
# LPG           5378
# CNG            571
# Hybrid         278
# Electric       104
# Name: count, dtype: int64

# %%
df.head()
# Out:
#            DateCrawled                            Name   Seller OfferType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  Private  Proposal
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private  Proposal
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private  Proposal
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private  Proposal
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private  Proposal
#
#    Price Abtest VehicleType  YearOfRegistration    Gearbox  PowerPS  Model  \
# 0    480   Test           -                1993     Manual        0   Golf
# 1  18300   Test       Coupe                2011     Manual      190      -
# 2   9800   Test         Suv                2004  Automatic      163  Grand
# 3   1500   Test  Kleinwagen                2001     Manual       75   Golf
# 4   3600   Test  Kleinwagen                2008     Manual       69  Fabia
#
# ...

# %%
df["Brand"].value_counts()
# Out:
# Brand
# volkswagen        79639
# bmw               40274
# opel              40136
# mercedes_benz     35307
# audi              32873
# ford              25573
# renault           17969
# peugeot           11027
# fiat               9676
# seat               7022
# mazda              5695
# skoda              5641
# smart              5249
# citroen            5182
# nissan             5037
# toyota             4694
# sonstige_autos     3982
# hyundai            3646
# mini               3394
# volvo              3327
# mitsubishi         3061
# honda              2836
# kia                2555
# alfa_romeo         2345
# suzuki             2327
# porsche            2215
# chevrolet          1845
# chrysler           1452
# dacia               900
# jeep                807
# daihatsu            806
# subaru              779
# land_rover          770
# jaguar              621
# trabant             591
# daewoo              542
# saab                530
# rover               490
# ...

# %%
lst_exception_rows = []
lst = []
for i in df["Brand"] :
    try :
        lst.append(i.capitalize())
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
lst.__len__() == df.__len__()
# Out:
# True

# %%
df["Brand"] = lst

# %%
df.head()
# Out:
#            DateCrawled                            Name   Seller OfferType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  Private  Proposal
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private  Proposal
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private  Proposal
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private  Proposal
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private  Proposal
#
#    Price Abtest VehicleType  YearOfRegistration    Gearbox  PowerPS  Model  \
# 0    480   Test           -                1993     Manual        0   Golf
# 1  18300   Test       Coupe                2011     Manual      190      -
# 2   9800   Test         Suv                2004  Automatic      163  Grand
# 3   1500   Test  Kleinwagen                2001     Manual       75   Golf
# 4   3600   Test  Kleinwagen                2008     Manual       69  Fabia
#
# ...

# %%
df["NotRepairedDamage"].value_counts()
# Out:
# NotRepairedDamage
# nein    263179
# ja       36285
# Name: count, dtype: int64

# %%
lst_exception_rows = []
lst = []
for i in df["NotRepairedDamage"] :
    try :
        if isna(i) : lst.append("-")
        elif i == "ja" : lst.append("Yes")
        elif i == "nein" : lst.append("No")
        else : raise
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
lst.__len__() == df.__len__()
# Out:
# True

# %%
df["NotRepairedDamage"] = lst

# %%
df.head()
# Out:
#            DateCrawled                            Name   Seller OfferType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  Private  Proposal
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private  Proposal
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private  Proposal
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private  Proposal
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private  Proposal
#
#    Price Abtest VehicleType  YearOfRegistration    Gearbox  PowerPS  Model  \
# 0    480   Test           -                1993     Manual        0   Golf
# 1  18300   Test       Coupe                2011     Manual      190      -
# 2   9800   Test         Suv                2004  Automatic      163  Grand
# 3   1500   Test  Kleinwagen                2001     Manual       75   Golf
# 4   3600   Test  Kleinwagen                2008     Manual       69  Fabia
#
# ...

# %%
df["DateCreated"]
# Out:
# 0         2016-03-24 00:00:00
# 1         2016-03-24 00:00:00
# 2         2016-03-14 00:00:00
# 3         2016-03-17 00:00:00
# 4         2016-03-31 00:00:00
#                  ...
# 371519    2016-03-14 00:00:00
# 371520    2016-03-05 00:00:00
# 371521    2016-03-19 00:00:00
# 371522    2016-03-20 00:00:00
# 371523    2016-03-07 00:00:00
# Name: DateCreated, Length: 371524, dtype: object

# %%
lst_exception_rows = []
lst = []
for i in df["DateCreated"] :
    try :
        lst.append(str(i)[:10])
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
lst.__len__() == df.__len__()
# Out:
# True

# %%
df["DateCreated"] = lst

# %%
df.head()
# Out:
#            DateCrawled                            Name   Seller OfferType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  Private  Proposal
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private  Proposal
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private  Proposal
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private  Proposal
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private  Proposal
#
#    Price Abtest VehicleType  YearOfRegistration    Gearbox  PowerPS  Model  \
# 0    480   Test           -                1993     Manual        0   Golf
# 1  18300   Test       Coupe                2011     Manual      190      -
# 2   9800   Test         Suv                2004  Automatic      163  Grand
# 3   1500   Test  Kleinwagen                2001     Manual       75   Golf
# 4   3600   Test  Kleinwagen                2008     Manual       69  Fabia
#
# ...

# %%
df["NoOfPictures"].value_counts()
# Out:
# NoOfPictures
# 0    371524
# Name: count, dtype: int64

# %%
df.head()
# Out:
#            DateCrawled                            Name   Seller OfferType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  Private  Proposal
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private  Proposal
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private  Proposal
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private  Proposal
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private  Proposal
#
#    Price Abtest VehicleType  YearOfRegistration    Gearbox  PowerPS  Model  \
# 0    480   Test           -                1993     Manual        0   Golf
# 1  18300   Test       Coupe                2011     Manual      190      -
# 2   9800   Test         Suv                2004  Automatic      163  Grand
# 3   1500   Test  Kleinwagen                2001     Manual       75   Golf
# 4   3600   Test  Kleinwagen                2008     Manual       69  Fabia
#
# ...

# %%
df.drop(columns=["NoOfPictures"],inplace= True)

# %%
df.head()
# Out:
#            DateCrawled                            Name   Seller OfferType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  Private  Proposal
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  Private  Proposal
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  Private  Proposal
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  Private  Proposal
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  Private  Proposal
#
#    Price Abtest VehicleType  YearOfRegistration    Gearbox  PowerPS  Model  \
# 0    480   Test           -                1993     Manual        0   Golf
# 1  18300   Test       Coupe                2011     Manual      190      -
# 2   9800   Test         Suv                2004  Automatic      163  Grand
# 3   1500   Test  Kleinwagen                2001     Manual       75   Golf
# 4   3600   Test  Kleinwagen                2008     Manual       69  Fabia
#
# ...

# %%
df["PostalCode"].value_counts()
# Out:
# PostalCode
# 10115    828
# 65428    637
# 66333    349
# 38518    326
# 44145    323
#         ...
# 67693      1
# 95367      1
# 63874      1
# 67377      1
# 31096      1
# Name: count, Length: 8150, dtype: int64

# %%
df[isna(df["PostalCode"])]
# Out:
# Empty DataFrame
# Columns: [DateCrawled, Name, Seller, OfferType, Price, Abtest, VehicleType, YearOfRegistration, Gearbox, PowerPS, Model, Kilometer, MonthOfRegistration, FuelType, Brand, NotRepairedDamage, DateCreated, PostalCode, LastSeen]
# Index: []

# %%
lst_exception_rows = []
for i in df["PostalCode"] :
    try :
        int(i)
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
df.head()
# Out:
#            DateCrawled  ...             LastSeen
# 0  2016-03-24 11:52:17  ...  2016-04-07 03:16:57
# 1  2016-03-24 10:58:45  ...  2016-04-07 01:46:50
# 2  2016-03-14 12:52:21  ...  2016-04-05 12:47:46
# 3  2016-03-17 16:54:04  ...  2016-03-17 17:40:17
# 4  2016-03-31 17:25:20  ...  2016-04-06 10:17:21
#
# [5 rows x 19 columns]

# %%
lst_exception_rows = []
lst = []
for i in df["Name"] :
    try :
        lst.append(i.replace("_"," "))
    except :
        lst_exception_rows.append(i)
lst_exception_rows
# Out:
# []

# %%
lst
# Out:
# ['Golf 3 1.6',
#  'A5 Sportback 2.7 Tdi',
#  'Jeep Grand Cherokee "Overland"',
#  'GOLF 4 1 4  3TÜRER',
#  'Skoda Fabia 1.4 TDI PD Classic',
#  'BMW 316i   e36 Limousine   Bastlerfahrzeug  Export',
#  'Peugeot 206 CC 110 Platinum',
#  'VW Derby Bj 80  Scheunenfund',
#  'Ford C   Max Titanium 1 0 L EcoBoost',
#  'VW Golf 4 5 tuerig zu verkaufen mit Anhaengerkupplung',
#  'Mazda 3 1.6 Sport',
#  'Volkswagen Passat Variant 2.0 TDI Comfortline',
#  'VW Passat Facelift 35i  "7Sitzer"',
#  'VW PASSAT 1.9 TDI 131 PS LEDER',
#  'Nissan Navara 2.5DPF SE4x4 Klima Sitzheizg Bluetooth.Doppelkabine',
#  'KA Lufthansa Edition 450€ VB',
#  'Polo 6n 1 4',
#  'Renault Twingo 1.2 16V Aut.',
#  'Ford C MAX 2.0 TDCi DPF Titanium',
#  'Mercedes Benz A 160 Classic Klima',
#  'Volkswagen Scirocco 1.4 TSI Sport',
#  'BMW 530i TÜV 7/17 Scheckheftgepflegt sehr guter Zustand',
#  'Opel Meriva 1.Hand TÜV 3.2018',
#  'Stadtflitzer',
#  'MERCEDES 200E  TÜV 04/2016',
#  'BMW 530d touring Vollausstattung NAVI',
# ...

# %%
df["Name"] = lst

# %%
df.head()
# Out:
#            DateCrawled  ...             LastSeen
# 0  2016-03-24 11:52:17  ...  2016-04-07 03:16:57
# 1  2016-03-24 10:58:45  ...  2016-04-07 01:46:50
# 2  2016-03-14 12:52:21  ...  2016-04-05 12:47:46
# 3  2016-03-17 16:54:04  ...  2016-03-17 17:40:17
# 4  2016-03-31 17:25:20  ...  2016-04-06 10:17:21
#
# [5 rows x 19 columns]

# %%
df.to_csv("auto_CLEANED.csv",index=False)
